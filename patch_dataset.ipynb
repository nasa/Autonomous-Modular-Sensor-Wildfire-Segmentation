# %%
import dataset_patching

# %%
# dataset_patching.union_masks('./data/ams_data/processed_images/ground_truth_masks/test')
# dataset_patching.union_masks('./data/ams_data/processed_images/ground_truth_masks/train')
# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/complete_images', './data/ams_data/processed_images/labelled_images/complete_images/train', './data/ams_data/processed_images/ground_truth_masks/train')
# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/complete_images', './data/ams_data/processed_images/labelled_images/complete_images/test', './data/ams_data/processed_images/ground_truth_masks/test')

# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/color_infrared', './data/ams_data/processed_images/labelled_images/color_infrared/train', './data/ams_data/processed_images/ground_truth_masks/train')
# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/color_infrared', './data/ams_data/processed_images/labelled_images/color_infrared/test', './data/ams_data/processed_images/ground_truth_masks/test')

# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/visual_spectrum', './data/ams_data/processed_images/labelled_images/visual_spectrum/train', './data/ams_data/processed_images/ground_truth_masks/train')
# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/visual_spectrum', './data/ams_data/processed_images/labelled_images/visual_spectrum/test', './data/ams_data/processed_images/ground_truth_masks/test')

# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/fire_emphasizing', './data/ams_data/processed_images/labelled_images/fire_emphasizing/train', './data/ams_data/processed_images/ground_truth_masks/train')
# dataset_patching.isolate_labelled_images('./data/ams_data/processed_images/fire_emphasizing', './data/ams_data/processed_images/labelled_images/fire_emphasizing/test', './data/ams_data/processed_images/ground_truth_masks/test')

# %% [markdown]
# *Note that running the below cells will overwrite the patched dataset!*

# %%
dataset_patching.generate_dataset_patches(image_folder = './data/ams_data/processed_images_new/labelled_images/complete_images/test', 
                         mask_folder = './data/ams_data/processed_images_new/ground_truth_masks/test', 
                         patch_image_folder = './data/ams_data/processed_images_new/patches/test/images', 
                         patch_mask_folder = './data/ams_data/processed_images_new/patches/test/labels')
# Out:
# 2

# %%
dataset_patching.generate_dataset_patches(image_folder = './data/ams_data/processed_images_new/labelled_images/complete_images/train', 
                         mask_folder = './data/ams_data/processed_images_new/ground_truth_masks/train', 
                         patch_image_folder = './data/ams_data/processed_images_new/patches/train/images', 
                         patch_mask_folder = './data/ams_data/processed_images_new/patches/train/labels')
# Out:
# 18

# %%
dataset_patching.generate_dataset_patches(image_folder = './data/ams_data/processed_images_new/labelled_images/complete_images/train', 
                         mask_folder = './data/ams_data/processed_images_new/ground_truth_masks/train', 
                         patch_image_folder = './data/ams_data/processed_images_new/patches/controlnet_data/images', 
                         patch_mask_folder = './data/ams_data/processed_images_new/patches/controlnet_data/labels')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/r9/ldxpmtds1rs7d725ygx8xhkm0000gn/T/ipykernel_52682/7062855.py in ?()
# ----> 1 dataset_patching.generate_dataset_patches(image_folder = './data/ams_data/processed_images_new/labelled_images/complete_images/train',
#       2                          mask_folder = './data/ams_data/processed_images_new/ground_truth_masks/train',
#       3                          patch_image_folder = './data/ams_data/processed_images_new/patches/controlnet_data/images',
#       4                          patch_mask_folder = './data/ams_data/processed_images_new/patches/controlnet_data/labels')
#
# ~/nasa/wildfire_detection_code_submission/dataset_patching.py in ?(image_folder, mask_folder, patch_image_folder, patch_mask_folder)
#      20     # patch the image
#      21     # store the 12 bands and 13th band separately
# ...

# %%
dataset_patching.generate_dataset_patches(image_folder = './data/ams_data/processed_images/labelled_images/complete_images/train', 
                         mask_folder = './data/ams_data/processed_images/ground_truth_masks/train', 
                         patch_image_folder = './data/ams_data/processed_images/patches/controlnet_masks_512/images', 
                         patch_mask_folder = './data/ams_data/processed_images/patches/controlnet_masks_512/labels')

# %%
dataset_patching.generate_dataset_patches(image_folder = './data/ams_data/processed_images/labelled_images/complete_images/train', 
                         mask_folder = './data/ams_data/processed_images/ground_truth_masks/train', 
                         patch_image_folder = './data/ams_data/processed_images/patches/controlnet_masks_temp2/images', 
                         patch_mask_folder = './data/ams_data/processed_images/patches/controlnet_masks_temp2/labels')

# %%
dataset_patching.generate_dataset_patches(image_folder = './data/other_normalization_scheme/train', 
                         mask_folder = './data/ams_data/processed_images/ground_truth_masks/train', 
                         patch_image_folder = './data/other_normalization_scheme/patches/train/images', 
                         patch_mask_folder = './data/other_normalization_scheme/patches/train/labels')
